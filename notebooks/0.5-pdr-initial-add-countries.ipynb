# %%
import pandas as pd

# Load the cleaned dataset
df = pd.read_csv('../data/interim/Meteorite_Landings_cleaned.csv')
df.head()
# Out:
#        name   id nametype        class  mass (g)  fall  year  latitude  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902 -33.16667
#
#    longitude    category
# 0    6.08333   Chondrite
# 1   10.23333   Chondrite
# 2 -113.00000   Chondrite
# 3  -99.90000  Achondrite
# 4  -64.95000   Chondrite

# %%
# Check the data types of the columns
df.dtypes
# Out:
# name          object
# id             int64
# nametype      object
# class         object
# mass (g)     float64
# fall          object
# year           int64
# latitude     float64
# longitude    float64
# category      object
# dtype: object

# %%
import reverse_geocode as rg

# Add country column to the dataset
def get_country(lat, lon):
    result = rg.search([(lat, lon)])
    return result[0]['country']

df['country'] = df.apply(lambda x: get_country(x['latitude'], x['longitude']), axis=1)
df.head()
# Out:
#        name   id nametype        class  mass (g)  fall  year  latitude  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902 -33.16667
#
#    longitude    category    country
# 0    6.08333   Chondrite    Germany
# 1   10.23333   Chondrite    Denmark
# 2 -113.00000   Chondrite     Canada
# 3  -99.90000  Achondrite     Mexico
# 4  -64.95000   Chondrite  Argentina

# %%
# Add city column to the dataset
def get_city(lat, lon):
    result = rg.search([(lat, lon)])
    return result[0]['city']

df['city'] = df.apply(lambda x: get_city(x['latitude'], x['longitude']), axis=1)
df.head()
# Out:
#        name   id nametype        class  mass (g)  fall  year  latitude  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902 -33.16667
#
#    longitude    category    country                city
# 0    6.08333   Chondrite    Germany              Aachen
# 1   10.23333   Chondrite    Denmark               Århus
# 2 -113.00000   Chondrite     Canada              Lamont
# 3  -99.90000  Achondrite     Mexico  Acapulco de Juárez
# 4  -64.95000   Chondrite  Argentina             Achiras

# %%
# Correct the country for the meteorites that fell in Antarctica
df.loc[df['latitude'] <= -60.0000, 'country'] = 'Antarctica'

# %%
# Correct the city for the meteorites that fell in Antarctica
df.loc[df['country'] == 'Antarctica', 'city'] = None

# %%
df.head()
# Out:
#        name   id nametype        class  mass (g)  fall  year  latitude  \
# 0    Aachen    1    Valid           L5      21.0  Fell  1880  50.77500
# 1    Aarhus    2    Valid           H6     720.0  Fell  1951  56.18333
# 2      Abee    6    Valid          EH4  107000.0  Fell  1952  54.21667
# 3  Acapulco   10    Valid  Acapulcoite    1914.0  Fell  1976  16.88333
# 4   Achiras  370    Valid           L6     780.0  Fell  1902 -33.16667
#
#    longitude    category    country                city
# 0    6.08333   Chondrite    Germany              Aachen
# 1   10.23333   Chondrite    Denmark               Århus
# 2 -113.00000   Chondrite     Canada              Lamont
# 3  -99.90000  Achondrite     Mexico  Acapulco de Juárez
# 4  -64.95000   Chondrite  Argentina             Achiras

# %%
# Save the dataset
df.to_csv('../data/Meteorite_Landings_20250108_addcountries.csv', index=False)
